# %%
import pandas as pd
import random

# %%
data = pd.read_csv("../../data/cleaned/yelp_academic_dataset_businesses_reviews_non_unique.csv")
# Out:
# /var/folders/gk/1_hpxk0x6bvfh9xs2r_splw40000gn/T/ipykernel_40346/1981857585.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../../data/cleaned/yelp_academic_dataset_businesses_reviews_non_unique.csv")

# %%
data.shape
# Out:
# (26804297, 17)

# %%
data.head()
# Out:
#               business_id                name      address          city  \
# 0  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  philadelphia
# 1  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  philadelphia
# 2  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  philadelphia
# 3  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  philadelphia
# 4  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  philadelphia
#
#   state postal_code   latitude  longitude  stars  review_count  is_open  \
# 0    PA       19107  39.955505 -75.155564    4.0            80        1
# 1    PA       19107  39.955505 -75.155564    4.0            80        1
# 2    PA       19107  39.955505 -75.155564    4.0            80        1
# 3    PA       19107  39.955505 -75.155564    4.0            80        1
# 4    PA       19107  39.955505 -75.155564    4.0            80        1
#
#                                           attributes  \
# ...

# %%
business_ids = list(data["business_id"].unique())
len(business_ids)
# Out:
# 56930

# %%
random_business_ids = random.sample(business_ids, 10)
random_business_ids
# Out:
# ['p8sgZPvVq39bIklMO7x6ng',
#  'Jc6MxMyCLp4DMfN4C1t1aQ',
#  'ndgereoj013wm-pyO5B-VA',
#  'RBn3LZUe_ZFrLsYDMh-hhg',
#  'O4dxdtqo625JFN0uFaDZiw',
#  '-yQIm7RUM9AvRA-ycnejjA',
#  'cWhEVY0KMmIRTVR-sjNusQ',
#  'calI2y44JJN497vsW1lF0g',
#  '0tiTIv9fHyrtLtOSkPLAwQ',
#  'IUx-QYV5pszE7gLky1JLhA']

# %%
filtered_data = data.loc[data["business_id"].isin(random_business_ids)]
filtered_data
# Out:
#                      business_id               name          address  \
# 1020364   Jc6MxMyCLp4DMfN4C1t1aQ  Pepo's Cuban Cafe    9939 4th St N
# 1020365   Jc6MxMyCLp4DMfN4C1t1aQ  Pepo's Cuban Cafe    9939 4th St N
# 1020366   Jc6MxMyCLp4DMfN4C1t1aQ  Pepo's Cuban Cafe    9939 4th St N
# 1020367   Jc6MxMyCLp4DMfN4C1t1aQ  Pepo's Cuban Cafe    9939 4th St N
# 1020368   Jc6MxMyCLp4DMfN4C1t1aQ  Pepo's Cuban Cafe    9939 4th St N
# ...                          ...                ...              ...
# 24042477  IUx-QYV5pszE7gLky1JLhA      Koke's Tavern  4419 Cookson Rd
# 24042478  IUx-QYV5pszE7gLky1JLhA      Koke's Tavern  4419 Cookson Rd
# 24042479  IUx-QYV5pszE7gLky1JLhA      Koke's Tavern  4419 Cookson Rd
# 24042480  IUx-QYV5pszE7gLky1JLhA      Koke's Tavern  4419 Cookson Rd
# 24042481  IUx-QYV5pszE7gLky1JLhA      Koke's Tavern  4419 Cookson Rd
#
#                       city state postal_code   latitude  longitude  stars  \
# ...

# %%
filtered_data.rename(columns={"text":"review_text"}, inplace=True)
# Out:
# /var/folders/gk/1_hpxk0x6bvfh9xs2r_splw40000gn/T/ipykernel_40346/793996678.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data.rename(columns={"text":"review_text"}, inplace=True)

# %%
filtered_data.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'hours', 'categories', 'review_id', 'user_id',
#        'review_text'],
#       dtype='object')

# %%
filtered_data.drop(columns=["categories", "attributes", "hours", "is_open"], inplace=True)
# Out:
# /var/folders/gk/1_hpxk0x6bvfh9xs2r_splw40000gn/T/ipykernel_40346/1702008894.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data.drop(columns=["categories", "attributes", "hours", "is_open"], inplace=True)

# %%
filtered_data.business_id.unique()
# Out:
# array(['Jc6MxMyCLp4DMfN4C1t1aQ', 'ndgereoj013wm-pyO5B-VA',
#        'cWhEVY0KMmIRTVR-sjNusQ', 'O4dxdtqo625JFN0uFaDZiw',
#        'calI2y44JJN497vsW1lF0g', '-yQIm7RUM9AvRA-ycnejjA',
#        '0tiTIv9fHyrtLtOSkPLAwQ', 'p8sgZPvVq39bIklMO7x6ng',
#        'RBn3LZUe_ZFrLsYDMh-hhg', 'IUx-QYV5pszE7gLky1JLhA'], dtype=object)

# %%
filtered_data.drop_duplicates(inplace=True)
# Out:
# /var/folders/gk/1_hpxk0x6bvfh9xs2r_splw40000gn/T/ipykernel_40346/3622531329.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data.drop_duplicates(inplace=True)

# %%
filtered_data.to_csv("../../data/cleaned/samples/yelp_academic_dataset_businesses_reviews_sample.csv", index=False)

# %%
restaurant_names = list(filtered_data.name.unique())
restaurant_names
# Out:
# ["Pepo's Cuban Cafe",
#  'Pickle Barrel Deli',
#  'Bona Cucina',
#  "Kelly's Bake Shop & Cafe",
#  "Applebee's Grill + Bar",
#  'Enoteca Pizzeria Wine Bar',
#  'Five Guys',
#  'New Orleans Coffee & Beignet',
#  "Aurora's Bistro",
#  "Koke's Tavern"]

# %%
filtered_data.head()
# Out:
#                     business_id               name        address  \
# 1020364  Jc6MxMyCLp4DMfN4C1t1aQ  Pepo's Cuban Cafe  9939 4th St N
# 1020365  Jc6MxMyCLp4DMfN4C1t1aQ  Pepo's Cuban Cafe  9939 4th St N
# 1020366  Jc6MxMyCLp4DMfN4C1t1aQ  Pepo's Cuban Cafe  9939 4th St N
# 1020367  Jc6MxMyCLp4DMfN4C1t1aQ  Pepo's Cuban Cafe  9939 4th St N
# 1020368  Jc6MxMyCLp4DMfN4C1t1aQ  Pepo's Cuban Cafe  9939 4th St N
#
#                    city state postal_code   latitude  longitude  stars  \
# 1020364  st. petersburg    FL       33702  27.863139 -82.638417    4.0
# 1020365  st. petersburg    FL       33702  27.863139 -82.638417    4.0
# 1020366  st. petersburg    FL       33702  27.863139 -82.638417    4.0
# 1020367  st. petersburg    FL       33702  27.863139 -82.638417    4.0
# 1020368  st. petersburg    FL       33702  27.863139 -82.638417    4.0
#
#          review_count               review_id                 user_id  \
# ...

# %%
filtered_data.loc[filtered_data["review_count"]<50]
# Out:
#                      business_id                name             address  \
# 2911885   ndgereoj013wm-pyO5B-VA  Pickle Barrel Deli  9520 Seminole Blvd
# 2911886   ndgereoj013wm-pyO5B-VA  Pickle Barrel Deli  9520 Seminole Blvd
# 2911887   ndgereoj013wm-pyO5B-VA  Pickle Barrel Deli  9520 Seminole Blvd
# 2911888   ndgereoj013wm-pyO5B-VA  Pickle Barrel Deli  9520 Seminole Blvd
# 2911889   ndgereoj013wm-pyO5B-VA  Pickle Barrel Deli  9520 Seminole Blvd
# ...                          ...                 ...                 ...
# 24042453  IUx-QYV5pszE7gLky1JLhA       Koke's Tavern     4419 Cookson Rd
# 24042454  IUx-QYV5pszE7gLky1JLhA       Koke's Tavern     4419 Cookson Rd
# 24042455  IUx-QYV5pszE7gLky1JLhA       Koke's Tavern     4419 Cookson Rd
# 24042456  IUx-QYV5pszE7gLky1JLhA       Koke's Tavern     4419 Cookson Rd
# 24042457  IUx-QYV5pszE7gLky1JLhA       Koke's Tavern     4419 Cookson Rd
#
#                       city state postal_code   latitude  longitude  stars  \
# ...

# %%
len(filtered_data.loc[filtered_data["name"]=="Pickle Barrel Deli"])
# Out:
# 11

# %%
reviews = filtered_data.loc[filtered_data["name"]=="Pickle Barrel Deli"]["review_text"]
reviews
# Out:
# 2911885    Amazingly huge sandwiches. Busy place and frie...
# 2911886    Order a steak and cheese hoagie with fries!!! ...
# 2911887    A good old-fashioned neighborhood deli. Not th...
# 2911888    This deli has been here FOREVER. The couple wh...
# 2911889    The pickle barrel is one of the finest delis i...
# 2911890    this place has the best reubens and chicken sa...
# 2911891    the best pastrami and rueben   sand. in town. ...
# 2911892    DON'T GO! I went in with a toddler (bi-racial)...
# 2911893    Apparently the woman with the bi-racial child ...
# 2911894    Nothing particularly stood out at this place. ...
# 2911895    Closed...not sure what happened but they are d...
# Name: review_text, dtype: object

# %%
filtered_data.review_text[18776610]
# Out:
# 'Talon personally I believe deserves a rise this young man worked so efficiently yet still made me and my family feel like we were wanted there as a customer. He even asked to make sure our food was good when I was getting ketchup even though he was clearly busy. Kudos to Talon!'

# %%
reviews_text = "".join(list(reviews))

import re
a = re.search(r'\b(ketchup)\b', reviews_text)
if a is not None:
    start = a.start()
    print(reviews_text[start:])
else:
    print("not found")
# Out:
# ketchup
#
# Positives
# * Friendly and attentive staff
# * Good Iced Tea
# * Nice fresh/soft bread
# * Roast Beef was perfect and freshClosed...not sure what happened but they are done...saw a sign on the door today when I went over to get a sandwich....very sad

# %%
filtered_data[filtered_data['review_text'].str.contains("ketchup")]["review_text"]
# Out:
# 2911894     Nothing particularly stood out at this place. ...
# 18776610    Talon personally I believe deserves a rise thi...
# Name: review_text, dtype: object
